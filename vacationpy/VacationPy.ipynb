# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import gmaps.datasets
import os
from pprint import pprint

# Import API key
from api_keys import g_key

# %%
print(g_key)
# Out:
# AIzaSyCCp5j8JAOws4F3dXILEAEN62pSa7X1S98

# %%
#!jupyter labextension install jupyter-matplotlib@0.3.0

# %%
#read in city weather data csv file

vacation_df = pd.read_csv("../output_data/cities.csv",index_col=0)

vacation_df.head(30)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Hobart -42.8794  147.3294     44.92        77          99
# 1            Havelock  34.8791  -76.9013     86.99        58           1
# 2              Atuona  -9.8000 -139.0333     77.97        70          96
# 3                 Vao -22.6667  167.4833     70.81        84          19
# 4          Codrington -38.2667  141.9667     44.98        76          99
# 5               Malpe  13.3500   74.7167     79.90        86          62
# 6             Ushuaia -54.8000  -68.3000     38.82        87          40
# 7   City of San Pedro  14.3500  121.0167     80.15        95          90
# 8           Cape Town -33.9258   18.4232     57.11        64           0
# 9             Mataura -46.1927  168.8643     38.48        90          95
# 10             Abalak  58.1286   68.5944     58.26        98          99
# 11             Torbay  47.6666  -52.7314     67.75        72          90
# 12       Puerto Ayora  -0.7393  -90.3518     78.76        84          31
# 13           Hamilton  39.1834  -84.5333     88.36        60           1
# 14        New Norfolk -42.7826  147.0587     44.58        83          96
# 15            Algiers  36.7525    3.0420     89.42        40          40
# 16             Touros  -5.1989  -35.4608     88.70        50          12
# 17         Rio Grande -32.0350  -52.0986     82.51        65           2
# 18           Shatrovo  56.5167   64.6333     60.42        91         100
# 19              Pevek  69.7008  170.3133     37.15        92          95
# 20          Busselton -33.6500  115.3333     56.08        76          97
# 21            Huarmey -10.0681  -78.1522     69.35        69          23
# 22          Hong Kong  22.2855  114.1577     85.98        88          89
# 23       Punta Arenas -53.1500  -70.9167     42.91        75          75
# 24       Longyearbyen  78.2186   15.6401     46.24        76          75
# 25       Ponta do Sol  32.6667  -17.1000     81.72        69           0
# 26            Manggar  -2.8833  108.2667     81.95        75           3
# 27               Nome  64.5011 -165.4064     48.27        87          90
# 28            Rikitea -23.1203 -134.9692     68.77        55           0
# 29           Bengkulu  -3.8004  102.2655     76.03        87          22
#
#     Wind Speed Country        Date
# 0         1.99      AU  1627148245
# 1         5.99      US  1627148245
# 2        16.20      PF  1627147805
# 3         5.68      NC  1627147805
# 4        23.40      AU  1627147806
# 5        10.58      IN  1627147806
# 6         5.75      AR  1627147806
# 7         2.30      PH  1627147807
# 8         2.30      ZA  1627148246
# 9         3.98      NZ  1627148246
# 10        2.71      RU  1627148246
# 11       13.80      CA  1627148247
# 12        8.99      EC  1627148247
# 13        1.99      US  1627148247
# 14        3.00      AU  1627148247
# 15        6.91      DZ  1627148076
# 16       19.77      BR  1627147809
# 17        5.30      BR  1627147810
# 18        1.97      RU  1627147810
# 19        7.23      RU  1627147810
# 20       16.20      AU  1627147811
# 21       11.21      PE  1627147811
# 22       11.01      HK  1627147629
# 23       14.97      CL  1627147542
# 24        5.75      SJ  1627147778
# 25        4.05      PT  1627147812
# 26       13.96      ID  1627147812
# 27        8.05      US  1627147812
# 28        2.33      PF  1627147773
# 29        4.23      ID  1627147813

# %%
#configure gmaps
gmaps.configure(api_key=g_key)

# %%
#create a heatmap showing humidity

locations = vacation_df[['Lat', 'Lng']]
weights = vacation_df['Humidity']
humidity_fig = gmaps.figure()
humidity_fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
humidity_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#check number of cities
vacation_df["City"].value_counts()
# Out:
# Cuxhaven      1
# Yeniseysk     1
# Takoradze     1
# College       1
# Marzuq        1
#              ..
# Dodge City    1
# Along         1
# Ushtobe       1
# Bariloche     1
# Kot Diji      1
# Name: City, Length: 544, dtype: int64

# %%
#drop any rows with null values and confirm drop
no_nulls = vacation_df.copy()

no_nulls.dropna(inplace=True)
no_nulls["City"].value_counts()
# Out:
# Cuxhaven      1
# Sitka         1
# Waingapu      1
# Muros         1
# Ihosy         1
#              ..
# Dodge City    1
# Along         1
# Ushtobe       1
# Bariloche     1
# Kot Diji      1
# Name: City, Length: 542, dtype: int64

# %%
ideal_weather_df = no_nulls.loc[(no_nulls["Humidity"] < 50) & (no_nulls["Wind Speed"] < 15) & 
                                (no_nulls["Max Temp"] > 60) & (no_nulls["Max Temp"] < 85)]

# %%
ideal_weather_df
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 47                     Torata -17.0769  -70.8433     68.90        18
# 71                 Port Keats -14.2500  129.5500     69.82        45
# 77                   Djambala  -2.5447   14.7533     80.28        32
# 95                     Castro -24.7911  -50.0119     70.63        40
# 110                  Stettler  52.3168 -112.7186     69.55        46
# 115                    Polson  47.6936 -114.1632     76.77        38
# 131                  Comarapa -17.9000  -64.4833     69.57        44
# 152            Afyonkarahisar  38.7500   30.6667     72.72        35
# 166               Buritizeiro -17.3511  -44.9622     82.26        24
# 167                   Ipameri -17.7219  -48.1597     80.40        23
# 169             Sioux Lookout  50.1001  -91.9170     79.18        47
# 181             San Cristobal   7.7669  -72.2250     80.78        48
# 218                   Ushtobe  45.2514   77.9838     80.60        25
# 244                      Tyup  42.7276   78.3648     65.17        43
# 254               Ladozhskaya  45.3081   39.9350     78.06        48
# 263                Mwinilunga -11.7358   24.4293     65.12        42
# 277                    Kalabo -14.9700   22.6814     67.05        36
# 286                    Bethel  41.3712  -73.4140     83.19        47
# 288  São Sebastião do Paraíso -20.9169  -46.9914     77.16        19
# 292                   Albanel  48.8832  -72.4487     78.78        38
# 306                   Changji  44.0167   87.3167     84.99        28
# 332                    Palmer  42.1584  -72.3287     83.77        41
# 345                   Vysokyy  49.8906   36.1200     78.78        36
# 347               Ouro Branco -20.5208  -43.6919     74.10        28
# 372                  Menongue -14.6585   17.6910     60.49        23
# 388          Denizli Province  37.8402   29.0698     74.25        30
# 395                   Karakol  42.4907   78.3936     66.33        27
# 399                   Pompéia -22.1086  -50.1717     84.07        17
# 408               Aksarayskiy  46.7924   48.0119     82.35        29
# 431                      Emba  48.8264   58.1442     77.88        40
# 433                   Kananga  -5.8958   22.4178     80.17        28
# 435                  Beroroha -21.6667   45.1667     67.89        39
# 444                     Sucúa  -2.4667  -78.1667     83.14        44
# 461                   Joensuu  62.6012   29.7632     67.10        46
# 469                  Linhares -19.3911  -40.0722     78.28        42
# 475               Fort Nelson  58.8053 -122.7002     65.79        48
# 476                   Buritis -15.6178  -46.4233     82.76        21
# 497                Camabatela  -8.1881   15.3750     69.93        23
# 499                   Saurimo  -9.6608   20.3916     71.06        28
# 521                 Kharabali  47.4196   47.2568     77.85        34
# 538                  Tshikapa  -6.4167   20.8000     83.53        25
#
#      Cloudiness  Wind Speed Country        Date
# 47            3        8.72      PE  1627147818
# 71           77        3.20      AU  1627147824
# 77           44        4.56      CG  1627147825
# 95            0        6.55      BR  1627147830
# 110          16        5.75      CA  1627147834
# 115           2        0.98      US  1627147836
# 131           1        8.66      BO  1627147840
# 152          34       11.45      TR  1627147845
# 166           0        6.78      BR  1627147848
# 167           0       10.13      BR  1627147849
# 169          90       12.66      CA  1627147797
# 181         100        6.67      VE  1627147756
# 218           0        9.04      KZ  1627147862
# 244           2        3.87      KG  1627147869
# 254          18        4.45      RU  1627147872
# 263          22        6.04      ZM  1627147875
# 277          12        6.76      ZM  1627147879
# 286           1       12.66      US  1627147775
# 288           0        8.41      BR  1627147882
# 292          67       11.50      CA  1627147883
# 306           0        6.71      CN  1627147887
# 332          20        1.99      US  1627147894
# 345           0        6.71      UA  1627147898
# 347           0        7.29      BR  1627147898
# 372           0        4.85      AO  1627147904
# 388          52        7.92      TR  1627147908
# 395           0        5.50      KG  1627147910
# 399           0        9.84      BR  1627147911
# 408          45        8.03      RU  1627147914
# 431          42        9.66      KZ  1627147920
# 433           7        3.65      CD  1627147920
# 435          73        9.64      MG  1627147921
# 444          40        5.75      EC  1627147923
# 461           0        6.91      FI  1627147928
# 469           6       10.42      BR  1627147817
# 475          75       12.66      CA  1627147931
# 476           3        7.31      BR  1627147931
# 497           0        5.12      AO  1627147937
# 499           1        3.22      AO  1627147937
# 521           9        5.44      RU  1627147944
# 538          19        3.91      CD  1627147949

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="
params = "&radius=5000&type=hotel&key="

cities_list = ideal_weather_df["City"]
countries_list = ideal_weather_df["Country"]
hotels_list = []
hotels_lat = []
hotels_lng = []

countries_list = []

for city in cities_list:
    try:
        row = ideal_weather_df.loc[ideal_weather_df['City']==city]
        loc = f"{row[1]},{row[2]}"
        response = requests.get(url + loc + params + g_key).json()
        hotels_list.append(response['results'][0]['name'])
        hotels_lat.append(response['results'][0]['geometry']['location']['lat'])
        hotels_lng.append(response['results'][0]['geometry']['location']['lng'])
    except:
        print(loc)
# Out:
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64
# 538   -6.4167
# Name: Lat, dtype: float64,538    20.8
# Name: Lng, dtype: float64

# %%
row
# Out:
#          City     Lat   Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 538  Tshikapa -6.4167  20.8     83.53        25          19        3.91
#
#     Country        Date
# 538      CD  1627147949

# %%
ideal_weather_df['Lat']
# Out:
# 47    -17.0769
# 71    -14.2500
# 77     -2.5447
# 95    -24.7911
# 110    52.3168
# 115    47.6936
# 131   -17.9000
# 152    38.7500
# 166   -17.3511
# 167   -17.7219
# 169    50.1001
# 181     7.7669
# 218    45.2514
# 244    42.7276
# 254    45.3081
# 263   -11.7358
# 277   -14.9700
# 286    41.3712
# 288   -20.9169
# 292    48.8832
# 306    44.0167
# 332    42.1584
# 345    49.8906
# 347   -20.5208
# 372   -14.6585
# 388    37.8402
# 395    42.4907
# 399   -22.1086
# 408    46.7924
# 431    48.8264
# 433    -5.8958
# 435   -21.6667
# 444    -2.4667
# 461    62.6012
# 469   -19.3911
# 475    58.8053
# 476   -15.6178
# 497    -8.1881
# 499    -9.6608
# 521    47.4196
# 538    -6.4167
# Name: Lat, dtype: float64

# %%
url + loc + params + g_key
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=47    -17.0769\n71    -14.2500\n77     -2.5447\n95    -24.7911\n110    52.3168\n115    47.6936\n131   -17.9000\n152    38.7500\n166   -17.3511\n167   -17.7219\n169    50.1001\n181     7.7669\n218    45.2514\n244    42.7276\n254    45.3081\n263   -11.7358\n277   -14.9700\n286    41.3712\n288   -20.9169\n292    48.8832\n306    44.0167\n332    42.1584\n345    49.8906\n347   -20.5208\n372   -14.6585\n388    37.8402\n395    42.4907\n399   -22.1086\n408    46.7924\n431    48.8264\n433    -5.8958\n435   -21.6667\n444    -2.4667\n461    62.6012\n469   -19.3911\n475    58.8053\n476   -15.6178\n497    -8.1881\n499    -9.6608\n521    47.4196\n538    -6.4167\nName: Lat, dtype: float64,47     -70.8433\n71     129.5500\n77      14.7533\n95     -50.0119\n110   -112.7186\n115   -114.1632\n131    -64.4833\n152     30.6667\n166    -44.9622\n167    -48.1597\n169    -91.9170\n181    -72.2250\n218     77.9838\n244     78.3648\n254     39.9350\n263     24.4293\n277     22.6814\n286    -73.4140\n288    -46.9914\n292    -72.4487\n306     87.3167\n332    -72.3287\n345     36.1200\n347    -43.6919\n372     17.6910\n388     29.0698\n395     78.3936\n399    -50.1717\n408     48.0119\n431     58.1442\n433     22.4178\n435     45.1667\n444    -78.1667\n461     29.7632\n469    -40.0722\n475   -122.7002\n476    -46.4233\n497     15.3750\n499     20.3916\n521     47.2568\n538     20.8000\nName: Lng, dtype: float64&radius=5000&type=hotel&key=AIzaSyCCp5j8JAOws4F3dXILEAEN62pSa7X1S98'

# %%
print(hotels_list)
# Out:
# []

# %%
response
# Out:
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}

# %%
if  response['results'][0]['name']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-5b1a5c65ecf0> in <module>
# ----> 1 response['results'][0]['name']
#
# IndexError: list index out of range

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="
params = "&radius=5000&type=hotel&key="
test = requests.get(url + "-17.0769" + "," + "-70.8433" + params + g_key).json()
test
print(url + "-17.0769" + "," + "-70.8433" + params)
pprint(test)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-17.0769,-70.8433&radius=5000&type=hotel&key=
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEBDqjq8vi2uDiSt1GFgnwlFit2MW79aspWlkD40hJ4O3wGjKysLBe0mfHXjIL2pARyqLS-vW7he7oCGCW2nLFDrQMJfYcFWtyHNT6tvTHWdjRJ2BinDJpazQXrDsfDjtlXyxDsUfPcHABkm5tvEIYCa8EPBllD8zcK_r9OCPR1zXZt-qSgL9flE3eFcyoADKKldJr8F3ZN9GoGCkgsuW_6Yr8fKFOdZp6CQIdIHdbhnZ6KTTHDpcOm5o2_4se88Y4VmX3dYstBQXGdrqPfjcaG1dvif_w_pwsoxFR0wEJwrW9q827H5LVsj4YxwlnsXc7s7Qagp9HeJcNIJ6ouS4YwdeFhrKGy2rqD09zcZAEinR8NQ2G0T7-ifpQwDOJz0YjkfsbeU027hedPma4UvmjOy8LBl82wXO4QJ4pcMF1lsZoIWBITQWQ',
#  'results': [{'geometry': {'location': {'lat': -17.0740344, 'lng': -70.8090222},
#                            'viewport': {'northeast': {'lat': -17.06987200696554,
#                                                       'lng': -70.80379481852673},
#                                         'southwest': {'lat': -17.09288542397179,
#                                                       'lng': -70.83304175107807}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'name': 'Villa Cuajone',
#               'place_id': 'ChIJn4usZnRgQ5ER8OxClFE7ELc',
#               'reference': 'ChIJn4usZnRgQ5ER8OxClFE7ELc',
#               'scope': 'GOOGLE',
#               'types': ['locality', 'political'],
#               'vicinity': 'Villa Cuajone'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.1109333, 'lng': -70.859971},
#                            'viewport': {'northeast': {'lat': -17.1095843197085,
#                                                       'lng': -70.8586220197085},
#                                         'southwest': {'lat': -17.11228228029151,
#                                                       'lng': -70.86131998029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Cerro Baúl',
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114381414666645808542">Carlos '
#                                                 'Manuel Cuayla Choque</a>'],
#                           'photo_reference': 'Aap_uEBhxZ3tjwdZ1pabdrthbFuMHfhkpm0aqobSVDLROIK-I6G5FatsUo6vtO-Gb3TLCcruCqf7zMWvSwRqzrW_mDLnVfg18fO1h4DKT8xI9RqDY_IH1SUb6S7AqhiHRslAzZNKNxD6XVGcsBB-a7LU39n-rXl_gZoepCJER4uwczZnvwc9',
#                           'width': 2048}],
#               'place_id': 'ChIJF7CNsSqeRJERcdM5ZTHIgSQ',
#               'plus_code': {'compound_code': 'V4QR+J2 El Común, Peru',
#                             'global_code': '57JFV4QR+J2'},
#               'rating': 4.7,
#               'reference': 'ChIJF7CNsSqeRJERcdM5ZTHIgSQ',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 19,
#               'vicinity': 'Peru'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0763814,
#                                         'lng': -70.84465589999999},
#                            'viewport': {'northeast': {'lat': -17.0750345697085,
#                                                       'lng': -70.84330556970849},
#                                         'southwest': {'lat': -17.0777325302915,
#                                                       'lng': -70.84600353029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png',
#               'name': 'Banco de la Nación',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJK3n-4URgQ5ERLcrV1lCnYak',
#               'plus_code': {'compound_code': 'W5F4+C4 Torata District, Peru',
#                             'global_code': '57JFW5F4+C4'},
#               'rating': 3,
#               'reference': 'ChIJK3n-4URgQ5ERLcrV1lCnYak',
#               'scope': 'GOOGLE',
#               'types': ['bank',
#                         'finance',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': 'Calle Torata Nro 32 Mz. U Lote 24, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.07671789999999,
#                                         'lng': -70.84400389999999},
#                            'viewport': {'northeast': {'lat': -17.0753399197085,
#                                                       'lng': -70.8426727197085},
#                                         'southwest': {'lat': -17.0780378802915,
#                                                       'lng': -70.84537068029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'name': 'District Municipality of Torata',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103785220517884518480">Guillermo '
#                                                 'Jorge Ramos Ochoa</a>'],
#                           'photo_reference': 'Aap_uEA7laZwt1w2hmCHXQlgDji3JEQ-OxFK0Lk3uk8RwUQneUjOWXHVMx6zBglCyvAuer_UopHARkZD3HfwkyqAfy681EBvmKak1aiKwYRI97XpaPyeN5APn5n0dc1QUOVjxc2cod5JpWfx5RukGIfzUxpPjUIgUlR98KobE8cHF-98sSx1',
#                           'width': 1920}],
#               'place_id': 'ChIJ-wVO5URgQ5ERwSUdN2R6OOk',
#               'plus_code': {'compound_code': 'W5F4+89 Torata District, Peru',
#                             'global_code': '57JFW5F4+89'},
#               'rating': 3.9,
#               'reference': 'ChIJ-wVO5URgQ5ERwSUdN2R6OOk',
#               'scope': 'GOOGLE',
#               'types': ['city_hall',
#                         'local_government_office',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 15,
#               'vicinity': 'Calle Torata Nº 53, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0771588,
#                                         'lng': -70.84491179999999},
#                            'viewport': {'northeast': {'lat': -17.0758061697085,
#                                                       'lng': -70.84356541970848},
#                                         'southwest': {'lat': -17.0785041302915,
#                                                       'lng': -70.84626338029149}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'COREDSO',
#               'place_id': 'ChIJuYHVA0VgQ5ERZ4mZHxwHrv0',
#               'plus_code': {'compound_code': 'W5F4+42 Torata District, Peru',
#                             'global_code': '57JFW5F4+42'},
#               'reference': 'ChIJuYHVA0VgQ5ERZ4mZHxwHrv0',
#               'scope': 'GOOGLE',
#               'types': ['general_contractor',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'Calle Torata N 34, Torata'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': -17.0763554, 'lng': -70.8429464},
#                            'viewport': {'northeast': {'lat': -17.0750642197085,
#                                                       'lng': -70.84167441970848},
#                                         'southwest': {'lat': -17.0777621802915,
#                                                       'lng': -70.8443723802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'name': 'II. EE. JOSE CARLOS MARIATEGUI - SECUNDARIA',
#               'permanently_closed': True,
#               'place_id': 'ChIJd9LRpANhQ5ERgZffIKjpvRs',
#               'plus_code': {'compound_code': 'W5F4+FR Torata District, Peru',
#                             'global_code': '57JFW5F4+FR'},
#               'reference': 'ChIJd9LRpANhQ5ERgZffIKjpvRs',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'vicinity': 'Calle 28 De Julio, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0773747, 'lng': -70.8438454},
#                            'viewport': {'northeast': {'lat': -17.0760551697085,
#                                                       'lng': -70.8425306697085},
#                                         'southwest': {'lat': -17.0787531302915,
#                                                       'lng': -70.8452286302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Agrodel',
#               'place_id': 'ChIJKdVsNllhQ5ERE2I7DD0oqAY',
#               'plus_code': {'compound_code': 'W5F4+3F Torata District, Peru',
#                             'global_code': '57JFW5F4+3F'},
#               'reference': 'ChIJKdVsNllhQ5ERE2I7DD0oqAY',
#               'scope': 'GOOGLE',
#               'types': ['food', 'point_of_interest', 'store', 'establishment'],
#               'vicinity': 'Calle Bolivar 15, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.07684949999999,
#                                         'lng': -70.8440324},
#                            'viewport': {'northeast': {'lat': -17.07542846970849,
#                                                       'lng': -70.8427276197085},
#                                         'southwest': {'lat': -17.0781264302915,
#                                                       'lng': -70.8454255802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Panaderia Artesanal "Don Victor"',
#               'photos': [{'height': 2560,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103924613432544875315">Michael '
#                                                 'F. Oblitas R.</a>'],
#                           'photo_reference': 'Aap_uEAlokF0GqAsJutXKyXxJtKSw4Ko5RrztyoHlhnDmoE1ZnsQgLZm8G72tgIUHL63oWxvJ_5s8ENt9DG-Js59oOeblBY-kp3xfDadiGHeS5eu5XsIpvN4Hlat2Iik1qPECFN6Vttul01zY_xnj6gNRJxl6EsjBfQqYTySkWwZTuTSvsrf',
#                           'width': 1440}],
#               'place_id': 'ChIJM2iU-kRgQ5ER6goXiDn2y_0',
#               'plus_code': {'compound_code': 'W5F4+79 Torata District, Peru',
#                             'global_code': '57JFW5F4+79'},
#               'rating': 3.6,
#               'reference': 'ChIJM2iU-kRgQ5ER6goXiDn2y_0',
#               'scope': 'GOOGLE',
#               'types': ['grocery_or_supermarket',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 5,
#               'vicinity': 'Calle Torata 51, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0775983, 'lng': -70.8436595},
#                            'viewport': {'northeast': {'lat': -17.0762729697085,
#                                                       'lng': -70.84233801970849},
#                                         'southwest': {'lat': -17.0789709302915,
#                                                       'lng': -70.8450359802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Licores y macerados Amalia',
#               'place_id': 'ChIJCc3CT4dhQ5ER4Oz_ldhjN1A',
#               'plus_code': {'compound_code': 'W5C4+XG Torata District, Peru',
#                             'global_code': '57JFW5C4+XG'},
#               'reference': 'ChIJCc3CT4dhQ5ER4Oz_ldhjN1A',
#               'scope': 'GOOGLE',
#               'types': ['liquor_store',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'vicinity': 'Calle Bolivar, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0772089, 'lng': -70.8440786},
#                            'viewport': {'northeast': {'lat': -17.0758645697085,
#                                                       'lng': -70.8427347697085},
#                                         'southwest': {'lat': -17.0785625302915,
#                                                       'lng': -70.8454327302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Macerado Ciruela Damasquina Amalia',
#               'place_id': 'ChIJDUa1AhFhQ5ERpKdqA6ny0Ok',
#               'plus_code': {'compound_code': 'W5F4+49 Torata District, Peru',
#                             'global_code': '57JFW5F4+49'},
#               'reference': 'ChIJDUa1AhFhQ5ERpKdqA6ny0Ok',
#               'scope': 'GOOGLE',
#               'types': ['grocery_or_supermarket',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'vicinity': 'Torata, Calle Omate, Pasaje Los jazmines A1'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0763153, 'lng': -70.8439636},
#                            'viewport': {'northeast': {'lat': -17.0749185197085,
#                                                       'lng': -70.84255281970849},
#                                         'southwest': {'lat': -17.0776164802915,
#                                                       'lng': -70.84525078029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#               'name': 'Iglesia San Agustín de Torata',
#               'photos': [{'height': 540,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109640167667156886039">Diana '
#                                                 'Santos</a>'],
#                           'photo_reference': 'Aap_uEB2fR-EL716ZgZRLFA7M1SlVToGKHm8f3qLwETldGVWH9heSWaqSz4_Q_boqzfzc-XxbhmTq2Cijkw1ylMbpqpA-MhI--0PwoM3r3zHET_SWXuLc_oX31J918OE8ElaCwRWNQO2z-vpyniZAjxeL7Mlzo8GqJgGMBXHQs-FCIE6h3wJ',
#                           'width': 720}],
#               'place_id': 'ChIJvXoe5kRgQ5ERebrDw3IRPf8',
#               'plus_code': {'compound_code': 'W5F4+FC Torata District, Peru',
#                             'global_code': '57JFW5F4+FC'},
#               'rating': 4,
#               'reference': 'ChIJvXoe5kRgQ5ERebrDw3IRPf8',
#               'scope': 'GOOGLE',
#               'types': ['church',
#                         'place_of_worship',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 15,
#               'vicinity': 'Torata District'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0772031, 'lng': -70.8442298},
#                            'viewport': {'northeast': {'lat': -17.0758325197085,
#                                                       'lng': -70.84285666970848},
#                                         'southwest': {'lat': -17.0785304802915,
#                                                       'lng': -70.8455546302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Calle Bolívar 13',
#               'photos': [{'height': 1280,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110146677301127894239">Félix '
#                                                 'Franco Bolaños</a>'],
#                           'photo_reference': 'Aap_uEArkRysmbPbTWQJ5Wqx1JhoIHv7I8HozjftRM8x0Gsz71wGWRj9IKeS_i1DgWg3mNTE8osFlFDIo-KjlcWYekO_VTXHPm1rqjXNeyVPOHLn6LEpcrEN2YUu01IpYeN64aXHHkCpzmaDOcKWpgAcfYA86deBnqmB9pxwai-S-yxlNA8k',
#                           'width': 720}],
#               'place_id': 'ChIJr19F-i9hQ5ER4Na6BcEPioQ',
#               'plus_code': {'compound_code': 'W5F4+48 Torata District, Peru',
#                             'global_code': '57JFW5F4+48'},
#               'reference': 'ChIJr19F-i9hQ5ER4Na6BcEPioQ',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'vicinity': 'Calle Bolivar 13, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0759571, 'lng': -70.8432115},
#                            'viewport': {'northeast': {'lat': -17.0745198197085,
#                                                       'lng': -70.8419024697085},
#                                         'southwest': {'lat': -17.07721778029151,
#                                                       'lng': -70.84460043029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'JUMACO SRL.',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3120,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108414060983919103212">julio '
#                                                 'manuel condori mamani</a>'],
#                           'photo_reference': 'Aap_uEAKGvxGfWyQ50UKjsJTdpRMLBjFYwtQdXIIazcIMEUhhmiNbaUfOZpcajhmkMjL6IzEsLiKHt7uLRYZEZwEmOWlO9uuIUMc__sUFQtaOGXb0RYcbMA7m1yebjhGxW49N_apwyRie1eMrQy6bcLJ9SyYcvTQ78KmYmV91rFIZ-IZrFfD',
#                           'width': 4160}],
#               'place_id': 'ChIJg2HwQplhQ5ER-Rti0dPkGTc',
#               'plus_code': {'compound_code': 'W5F4+JP Torata District, Peru',
#                             'global_code': '57JFW5F4+JP'},
#               'reference': 'ChIJg2HwQplhQ5ER-Rti0dPkGTc',
#               'scope': 'GOOGLE',
#               'types': ['general_contractor',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'Av. Principal Yacango Mz.M lote 1B C.P, yacango, '
#                           'Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0759571, 'lng': -70.8432115},
#                            'viewport': {'northeast': {'lat': -17.0745198197085,
#                                                       'lng': -70.8419024697085},
#                                         'southwest': {'lat': -17.07721778029151,
#                                                       'lng': -70.84460043029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'name': 'Restaurante Virgen de la Candelaria',
#               'place_id': 'ChIJQV2W-RBhQ5ERgnUbupfU5PI',
#               'plus_code': {'compound_code': 'W5F4+JP Torata District, Peru',
#                             'global_code': '57JFW5F4+JP'},
#               'reference': 'ChIJQV2W-RBhQ5ERgnUbupfU5PI',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': 'Peru'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0765437, 'lng': -70.8443161},
#                            'viewport': {'northeast': {'lat': -17.0752956197085,
#                                                       'lng': -70.8429051697085},
#                                         'southwest': {'lat': -17.0779935802915,
#                                                       'lng': -70.84560313029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#               'name': 'Plaza de Armas de Torata',
#               'place_id': 'ChIJnxj4KjdhQ5ERBLJheLQBMOY',
#               'plus_code': {'compound_code': 'W5F4+97 Torata District, Peru',
#                             'global_code': '57JFW5F4+97'},
#               'reference': 'ChIJnxj4KjdhQ5ERBLJheLQBMOY',
#               'scope': 'GOOGLE',
#               'types': ['park', 'point_of_interest', 'establishment'],
#               'vicinity': 'Plaza de Armas de, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0763604, 'lng': -70.8444026},
#                            'viewport': {'northeast': {'lat': -17.0749800197085,
#                                                       'lng': -70.8430734697085},
#                                         'southwest': {'lat': -17.07767798029151,
#                                                       'lng': -70.8457714302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'MULTISERVICIOS "D Y D" LEO',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJQe8X_p1hQ5ERZRzu7x6EEVw',
#               'plus_code': {'compound_code': 'W5F4+F6 Torata District, Peru',
#                             'global_code': '57JFW5F4+F6'},
#               'rating': 5,
#               'reference': 'ChIJQe8X_p1hQ5ERZRzu7x6EEVw',
#               'scope': 'GOOGLE',
#               'types': ['supermarket',
#                         'grocery_or_supermarket',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': '18100, Torata'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0761446, 'lng': -70.8442922},
#                            'viewport': {'northeast': {'lat': -17.0747909197085,
#                                                       'lng': -70.8429361197085},
#                                         'southwest': {'lat': -17.0774888802915,
#                                                       'lng': -70.8456340802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'name': 'Comisaria Torata',
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109067215938001456621">From '
#                                                 'a Google User</a>'],
#                           'photo_reference': 'Aap_uECVLdzGb3kRz1fsINgYsODQ0RSf4oL1mRSXYeqb0psUE9Ev2pfOOrP6SvH0zZZ8aSG7IhZU8OMp2bJTVXwjrBHMo4KGm-x61Ig8S3HysXmgY5122mkDRab6QOwezUYVq_IyDQoKWku2SuHxdS5C4qTBmOPJ7DUpF38iPJ6Nkq4OeKWr',
#                           'width': 4608}],
#               'place_id': 'ChIJVbRJ50RgQ5ERKdlrK5WHTHw',
#               'plus_code': {'compound_code': 'W5F4+G7 Torata District, Peru',
#                             'global_code': '57JFW5F4+G7'},
#               'rating': 4.6,
#               'reference': 'ChIJVbRJ50RgQ5ERKdlrK5WHTHw',
#               'scope': 'GOOGLE',
#               'types': ['local_government_office',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': 'Torata District'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -17.0766403, 'lng': -70.8446227},
#                            'viewport': {'northeast': {'lat': -17.0752975697085,
#                                                       'lng': -70.84328256970849},
#                                         'southwest': {'lat': -17.0779955302915,
#                                                       'lng': -70.8459805302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'name': 'Lodging Sra. Tina Vera',
#               'place_id': 'ChIJQ9d9o9lhQ5ERlzuVRRlNs7w',
#               'plus_code': {'compound_code': 'W5F4+85 Torata District, Peru',
#                             'global_code': '57JFW5F4+85'},
#               'reference': 'ChIJQ9d9o9lhQ5ERlzuVRRlNs7w',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Torata'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': -17.0776771, 'lng': -70.8445356},
#                            'viewport': {'northeast': {'lat': -17.0762785697085,
#                                                       'lng': -70.8431892697085},
#                                         'southwest': {'lat': -17.0789765302915,
#                                                       'lng': -70.84588723029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': 'Local del Adulto',
#               'permanently_closed': True,
#               'place_id': 'ChIJEQACVURgQ5ERXXqhPYab9nQ',
#               'plus_code': {'compound_code': 'W5C4+W5 Torata District, Peru',
#                             'global_code': '57JFW5C4+W5'},
#               'rating': 4,
#               'reference': 'ChIJEQACVURgQ5ERXXqhPYab9nQ',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Calle Torata 37, Torata'},
#              {'geometry': {'location': {'lat': -17.0759571, 'lng': -70.8432115},
#                            'viewport': {'northeast': {'lat': -17.07245649674261,
#                                                       'lng': -70.83735470340376},
#                                         'southwest': {'lat': -17.08283564151187,
#                                                       'lng': -70.84902753669058}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'name': 'Torata District',
#               'photos': [{'height': 4128,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116367668835137240263">ivette '
#                                                 'carrera</a>'],
#                           'photo_reference': 'Aap_uEC5NKgw4IjIxq5lYRs33Zlqmnvi759rcwiqmTKL2dOXzML8K6gSvmk7_pc1q3mbShg7UzrpGm6H_PggXsEDVbCt8ckDWkfzflUw7nGB5ylxwL3_aqKsoCdG0aAs8-FvWJV78mCKeTwuc9ZqUyfF6M_rqsQv4nrlRJh2OVwyMc-LCg9l',
#                           'width': 3096}],
#               'place_id': 'ChIJwaTn9kNgQ5ERgCIf5AVy-WU',
#               'reference': 'ChIJwaTn9kNgQ5ERgCIf5AVy-WU',
#               'scope': 'GOOGLE',
#               'types': ['locality', 'political'],
#               'vicinity': 'Torata District'}],
#  'status': 'OK'}

# %%
test['results'][0]['geometry']['location']['lat']
# Out:
# -17.0740344

# %%
test
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEBDqjq8vi2uDiSt1GFgnwlFit2MW79aspWlkD40hJ4O3wGjKysLBe0mfHXjIL2pARyqLS-vW7he7oCGCW2nLFDrQMJfYcFWtyHNT6tvTHWdjRJ2BinDJpazQXrDsfDjtlXyxDsUfPcHABkm5tvEIYCa8EPBllD8zcK_r9OCPR1zXZt-qSgL9flE3eFcyoADKKldJr8F3ZN9GoGCkgsuW_6Yr8fKFOdZp6CQIdIHdbhnZ6KTTHDpcOm5o2_4se88Y4VmX3dYstBQXGdrqPfjcaG1dvif_w_pwsoxFR0wEJwrW9q827H5LVsj4YxwlnsXc7s7Qagp9HeJcNIJ6ouS4YwdeFhrKGy2rqD09zcZAEinR8NQ2G0T7-ifpQwDOJz0YjkfsbeU027hedPma4UvmjOy8LBl82wXO4QJ4pcMF1lsZoIWBITQWQ',
#  'results': [{'geometry': {'location': {'lat': -17.0740344,
#      'lng': -70.8090222},
#     'viewport': {'northeast': {'lat': -17.06987200696554,
#       'lng': -70.80379481852673},
#      'southwest': {'lat': -17.09288542397179, 'lng': -70.83304175107807}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#    'name': 'Villa Cuajone',
#    'place_id': 'ChIJn4usZnRgQ5ER8OxClFE7ELc',
#    'reference': 'ChIJn4usZnRgQ5ER8OxClFE7ELc',
#    'scope': 'GOOGLE',
#    'types': ['locality', 'political'],
#    'vicinity': 'Villa Cuajone'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.1109333, 'lng': -70.859971},
#     'viewport': {'northeast': {'lat': -17.1095843197085,
#       'lng': -70.8586220197085},
#      'southwest': {'lat': -17.11228228029151, 'lng': -70.86131998029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Cerro Baúl',
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114381414666645808542">Carlos Manuel Cuayla Choque</a>'],
#      'photo_reference': 'Aap_uEBhxZ3tjwdZ1pabdrthbFuMHfhkpm0aqobSVDLROIK-I6G5FatsUo6vtO-Gb3TLCcruCqf7zMWvSwRqzrW_mDLnVfg18fO1h4DKT8xI9RqDY_IH1SUb6S7AqhiHRslAzZNKNxD6XVGcsBB-a7LU39n-rXl_gZoepCJER4uwczZnvwc9',
#      'width': 2048}],
#    'place_id': 'ChIJF7CNsSqeRJERcdM5ZTHIgSQ',
#    'plus_code': {'compound_code': 'V4QR+J2 El Común, Peru',
#     'global_code': '57JFV4QR+J2'},
#    'rating': 4.7,
#    'reference': 'ChIJF7CNsSqeRJERcdM5ZTHIgSQ',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': 'Peru'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0763814, 'lng': -70.84465589999999},
#     'viewport': {'northeast': {'lat': -17.0750345697085,
#       'lng': -70.84330556970849},
#      'southwest': {'lat': -17.0777325302915, 'lng': -70.84600353029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png',
#    'name': 'Banco de la Nación',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJK3n-4URgQ5ERLcrV1lCnYak',
#    'plus_code': {'compound_code': 'W5F4+C4 Torata District, Peru',
#     'global_code': '57JFW5F4+C4'},
#    'rating': 3,
#    'reference': 'ChIJK3n-4URgQ5ERLcrV1lCnYak',
#    'scope': 'GOOGLE',
#    'types': ['bank', 'finance', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Calle Torata Nro 32 Mz. U Lote 24, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.07671789999999,
#      'lng': -70.84400389999999},
#     'viewport': {'northeast': {'lat': -17.0753399197085,
#       'lng': -70.8426727197085},
#      'southwest': {'lat': -17.0780378802915, 'lng': -70.84537068029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'District Municipality of Torata',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103785220517884518480">Guillermo Jorge Ramos Ochoa</a>'],
#      'photo_reference': 'Aap_uEA7laZwt1w2hmCHXQlgDji3JEQ-OxFK0Lk3uk8RwUQneUjOWXHVMx6zBglCyvAuer_UopHARkZD3HfwkyqAfy681EBvmKak1aiKwYRI97XpaPyeN5APn5n0dc1QUOVjxc2cod5JpWfx5RukGIfzUxpPjUIgUlR98KobE8cHF-98sSx1',
#      'width': 1920}],
#    'place_id': 'ChIJ-wVO5URgQ5ERwSUdN2R6OOk',
#    'plus_code': {'compound_code': 'W5F4+89 Torata District, Peru',
#     'global_code': '57JFW5F4+89'},
#    'rating': 3.9,
#    'reference': 'ChIJ-wVO5URgQ5ERwSUdN2R6OOk',
#    'scope': 'GOOGLE',
#    'types': ['city_hall',
#     'local_government_office',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': 'Calle Torata Nº 53, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0771588, 'lng': -70.84491179999999},
#     'viewport': {'northeast': {'lat': -17.0758061697085,
#       'lng': -70.84356541970848},
#      'southwest': {'lat': -17.0785041302915, 'lng': -70.84626338029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'COREDSO',
#    'place_id': 'ChIJuYHVA0VgQ5ERZ4mZHxwHrv0',
#    'plus_code': {'compound_code': 'W5F4+42 Torata District, Peru',
#     'global_code': '57JFW5F4+42'},
#    'reference': 'ChIJuYHVA0VgQ5ERZ4mZHxwHrv0',
#    'scope': 'GOOGLE',
#    'types': ['general_contractor', 'point_of_interest', 'establishment'],
#    'vicinity': 'Calle Torata N 34, Torata'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': -17.0763554, 'lng': -70.8429464},
#     'viewport': {'northeast': {'lat': -17.0750642197085,
#       'lng': -70.84167441970848},
#      'southwest': {'lat': -17.0777621802915, 'lng': -70.8443723802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'name': 'II. EE. JOSE CARLOS MARIATEGUI - SECUNDARIA',
#    'permanently_closed': True,
#    'place_id': 'ChIJd9LRpANhQ5ERgZffIKjpvRs',
#    'plus_code': {'compound_code': 'W5F4+FR Torata District, Peru',
#     'global_code': '57JFW5F4+FR'},
#    'reference': 'ChIJd9LRpANhQ5ERgZffIKjpvRs',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': 'Calle 28 De Julio, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0773747, 'lng': -70.8438454},
#     'viewport': {'northeast': {'lat': -17.0760551697085,
#       'lng': -70.8425306697085},
#      'southwest': {'lat': -17.0787531302915, 'lng': -70.8452286302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Agrodel',
#    'place_id': 'ChIJKdVsNllhQ5ERE2I7DD0oqAY',
#    'plus_code': {'compound_code': 'W5F4+3F Torata District, Peru',
#     'global_code': '57JFW5F4+3F'},
#    'reference': 'ChIJKdVsNllhQ5ERE2I7DD0oqAY',
#    'scope': 'GOOGLE',
#    'types': ['food', 'point_of_interest', 'store', 'establishment'],
#    'vicinity': 'Calle Bolivar 15, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.07684949999999, 'lng': -70.8440324},
#     'viewport': {'northeast': {'lat': -17.07542846970849,
#       'lng': -70.8427276197085},
#      'southwest': {'lat': -17.0781264302915, 'lng': -70.8454255802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Panaderia Artesanal "Don Victor"',
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103924613432544875315">Michael F. Oblitas R.</a>'],
#      'photo_reference': 'Aap_uEAlokF0GqAsJutXKyXxJtKSw4Ko5RrztyoHlhnDmoE1ZnsQgLZm8G72tgIUHL63oWxvJ_5s8ENt9DG-Js59oOeblBY-kp3xfDadiGHeS5eu5XsIpvN4Hlat2Iik1qPECFN6Vttul01zY_xnj6gNRJxl6EsjBfQqYTySkWwZTuTSvsrf',
#      'width': 1440}],
#    'place_id': 'ChIJM2iU-kRgQ5ER6goXiDn2y_0',
#    'plus_code': {'compound_code': 'W5F4+79 Torata District, Peru',
#     'global_code': '57JFW5F4+79'},
#    'rating': 3.6,
#    'reference': 'ChIJM2iU-kRgQ5ER6goXiDn2y_0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Calle Torata 51, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0775983, 'lng': -70.8436595},
#     'viewport': {'northeast': {'lat': -17.0762729697085,
#       'lng': -70.84233801970849},
#      'southwest': {'lat': -17.0789709302915, 'lng': -70.8450359802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Licores y macerados Amalia',
#    'place_id': 'ChIJCc3CT4dhQ5ER4Oz_ldhjN1A',
#    'plus_code': {'compound_code': 'W5C4+XG Torata District, Peru',
#     'global_code': '57JFW5C4+XG'},
#    'reference': 'ChIJCc3CT4dhQ5ER4Oz_ldhjN1A',
#    'scope': 'GOOGLE',
#    'types': ['liquor_store', 'point_of_interest', 'store', 'establishment'],
#    'vicinity': 'Calle Bolivar, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0772089, 'lng': -70.8440786},
#     'viewport': {'northeast': {'lat': -17.0758645697085,
#       'lng': -70.8427347697085},
#      'southwest': {'lat': -17.0785625302915, 'lng': -70.8454327302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Macerado Ciruela Damasquina Amalia',
#    'place_id': 'ChIJDUa1AhFhQ5ERpKdqA6ny0Ok',
#    'plus_code': {'compound_code': 'W5F4+49 Torata District, Peru',
#     'global_code': '57JFW5F4+49'},
#    'reference': 'ChIJDUa1AhFhQ5ERpKdqA6ny0Ok',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'vicinity': 'Torata, Calle Omate, Pasaje Los jazmines A1'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0763153, 'lng': -70.8439636},
#     'viewport': {'northeast': {'lat': -17.0749185197085,
#       'lng': -70.84255281970849},
#      'southwest': {'lat': -17.0776164802915, 'lng': -70.84525078029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#    'name': 'Iglesia San Agustín de Torata',
#    'photos': [{'height': 540,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109640167667156886039">Diana Santos</a>'],
#      'photo_reference': 'Aap_uEB2fR-EL716ZgZRLFA7M1SlVToGKHm8f3qLwETldGVWH9heSWaqSz4_Q_boqzfzc-XxbhmTq2Cijkw1ylMbpqpA-MhI--0PwoM3r3zHET_SWXuLc_oX31J918OE8ElaCwRWNQO2z-vpyniZAjxeL7Mlzo8GqJgGMBXHQs-FCIE6h3wJ',
#      'width': 720}],
#    'place_id': 'ChIJvXoe5kRgQ5ERebrDw3IRPf8',
#    'plus_code': {'compound_code': 'W5F4+FC Torata District, Peru',
#     'global_code': '57JFW5F4+FC'},
#    'rating': 4,
#    'reference': 'ChIJvXoe5kRgQ5ERebrDw3IRPf8',
#    'scope': 'GOOGLE',
#    'types': ['church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': 'Torata District'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0772031, 'lng': -70.8442298},
#     'viewport': {'northeast': {'lat': -17.0758325197085,
#       'lng': -70.84285666970848},
#      'southwest': {'lat': -17.0785304802915, 'lng': -70.8455546302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Calle Bolívar 13',
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110146677301127894239">Félix Franco Bolaños</a>'],
#      'photo_reference': 'Aap_uEArkRysmbPbTWQJ5Wqx1JhoIHv7I8HozjftRM8x0Gsz71wGWRj9IKeS_i1DgWg3mNTE8osFlFDIo-KjlcWYekO_VTXHPm1rqjXNeyVPOHLn6LEpcrEN2YUu01IpYeN64aXHHkCpzmaDOcKWpgAcfYA86deBnqmB9pxwai-S-yxlNA8k',
#      'width': 720}],
#    'place_id': 'ChIJr19F-i9hQ5ER4Na6BcEPioQ',
#    'plus_code': {'compound_code': 'W5F4+48 Torata District, Peru',
#     'global_code': '57JFW5F4+48'},
#    'reference': 'ChIJr19F-i9hQ5ER4Na6BcEPioQ',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': 'Calle Bolivar 13, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0759571, 'lng': -70.8432115},
#     'viewport': {'northeast': {'lat': -17.0745198197085,
#       'lng': -70.8419024697085},
#      'southwest': {'lat': -17.07721778029151, 'lng': -70.84460043029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'JUMACO SRL.',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108414060983919103212">julio manuel condori mamani</a>'],
#      'photo_reference': 'Aap_uEAKGvxGfWyQ50UKjsJTdpRMLBjFYwtQdXIIazcIMEUhhmiNbaUfOZpcajhmkMjL6IzEsLiKHt7uLRYZEZwEmOWlO9uuIUMc__sUFQtaOGXb0RYcbMA7m1yebjhGxW49N_apwyRie1eMrQy6bcLJ9SyYcvTQ78KmYmV91rFIZ-IZrFfD',
#      'width': 4160}],
#    'place_id': 'ChIJg2HwQplhQ5ER-Rti0dPkGTc',
#    'plus_code': {'compound_code': 'W5F4+JP Torata District, Peru',
#     'global_code': '57JFW5F4+JP'},
#    'reference': 'ChIJg2HwQplhQ5ER-Rti0dPkGTc',
#    'scope': 'GOOGLE',
#    'types': ['general_contractor', 'point_of_interest', 'establishment'],
#    'vicinity': 'Av. Principal Yacango Mz.M lote 1B C.P, yacango, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0759571, 'lng': -70.8432115},
#     'viewport': {'northeast': {'lat': -17.0745198197085,
#       'lng': -70.8419024697085},
#      'southwest': {'lat': -17.07721778029151, 'lng': -70.84460043029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'name': 'Restaurante Virgen de la Candelaria',
#    'place_id': 'ChIJQV2W-RBhQ5ERgnUbupfU5PI',
#    'plus_code': {'compound_code': 'W5F4+JP Torata District, Peru',
#     'global_code': '57JFW5F4+JP'},
#    'reference': 'ChIJQV2W-RBhQ5ERgnUbupfU5PI',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'vicinity': 'Peru'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0765437, 'lng': -70.8443161},
#     'viewport': {'northeast': {'lat': -17.0752956197085,
#       'lng': -70.8429051697085},
#      'southwest': {'lat': -17.0779935802915, 'lng': -70.84560313029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#    'name': 'Plaza de Armas de Torata',
#    'place_id': 'ChIJnxj4KjdhQ5ERBLJheLQBMOY',
#    'plus_code': {'compound_code': 'W5F4+97 Torata District, Peru',
#     'global_code': '57JFW5F4+97'},
#    'reference': 'ChIJnxj4KjdhQ5ERBLJheLQBMOY',
#    'scope': 'GOOGLE',
#    'types': ['park', 'point_of_interest', 'establishment'],
#    'vicinity': 'Plaza de Armas de, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0763604, 'lng': -70.8444026},
#     'viewport': {'northeast': {'lat': -17.0749800197085,
#       'lng': -70.8430734697085},
#      'southwest': {'lat': -17.07767798029151, 'lng': -70.8457714302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'MULTISERVICIOS "D Y D" LEO',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJQe8X_p1hQ5ERZRzu7x6EEVw',
#    'plus_code': {'compound_code': 'W5F4+F6 Torata District, Peru',
#     'global_code': '57JFW5F4+F6'},
#    'rating': 5,
#    'reference': 'ChIJQe8X_p1hQ5ERZRzu7x6EEVw',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '18100, Torata'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0761446, 'lng': -70.8442922},
#     'viewport': {'northeast': {'lat': -17.0747909197085,
#       'lng': -70.8429361197085},
#      'southwest': {'lat': -17.0774888802915, 'lng': -70.8456340802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'Comisaria Torata',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109067215938001456621">From a Google User</a>'],
#      'photo_reference': 'Aap_uECVLdzGb3kRz1fsINgYsODQ0RSf4oL1mRSXYeqb0psUE9Ev2pfOOrP6SvH0zZZ8aSG7IhZU8OMp2bJTVXwjrBHMo4KGm-x61Ig8S3HysXmgY5122mkDRab6QOwezUYVq_IyDQoKWku2SuHxdS5C4qTBmOPJ7DUpF38iPJ6Nkq4OeKWr',
#      'width': 4608}],
#    'place_id': 'ChIJVbRJ50RgQ5ERKdlrK5WHTHw',
#    'plus_code': {'compound_code': 'W5F4+G7 Torata District, Peru',
#     'global_code': '57JFW5F4+G7'},
#    'rating': 4.6,
#    'reference': 'ChIJVbRJ50RgQ5ERKdlrK5WHTHw',
#    'scope': 'GOOGLE',
#    'types': ['local_government_office', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 8,
#    'vicinity': 'Torata District'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -17.0766403, 'lng': -70.8446227},
#     'viewport': {'northeast': {'lat': -17.0752975697085,
#       'lng': -70.84328256970849},
#      'southwest': {'lat': -17.0779955302915, 'lng': -70.8459805302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Lodging Sra. Tina Vera',
#    'place_id': 'ChIJQ9d9o9lhQ5ERlzuVRRlNs7w',
#    'plus_code': {'compound_code': 'W5F4+85 Torata District, Peru',
#     'global_code': '57JFW5F4+85'},
#    'reference': 'ChIJQ9d9o9lhQ5ERlzuVRRlNs7w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Torata'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': -17.0776771, 'lng': -70.8445356},
#     'viewport': {'northeast': {'lat': -17.0762785697085,
#       'lng': -70.8431892697085},
#      'southwest': {'lat': -17.0789765302915, 'lng': -70.84588723029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Local del Adulto',
#    'permanently_closed': True,
#    'place_id': 'ChIJEQACVURgQ5ERXXqhPYab9nQ',
#    'plus_code': {'compound_code': 'W5C4+W5 Torata District, Peru',
#     'global_code': '57JFW5C4+W5'},
#    'rating': 4,
#    'reference': 'ChIJEQACVURgQ5ERXXqhPYab9nQ',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Calle Torata 37, Torata'},
#   {'geometry': {'location': {'lat': -17.0759571, 'lng': -70.8432115},
#     'viewport': {'northeast': {'lat': -17.07245649674261,
#       'lng': -70.83735470340376},
#      'southwest': {'lat': -17.08283564151187, 'lng': -70.84902753669058}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#    'name': 'Torata District',
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116367668835137240263">ivette carrera</a>'],
#      'photo_reference': 'Aap_uEC5NKgw4IjIxq5lYRs33Zlqmnvi759rcwiqmTKL2dOXzML8K6gSvmk7_pc1q3mbShg7UzrpGm6H_PggXsEDVbCt8ckDWkfzflUw7nGB5ylxwL3_aqKsoCdG0aAs8-FvWJV78mCKeTwuc9ZqUyfF6M_rqsQv4nrlRJh2OVwyMc-LCg9l',
#      'width': 3096}],
#    'place_id': 'ChIJwaTn9kNgQ5ERgCIf5AVy-WU',
#    'reference': 'ChIJwaTn9kNgQ5ERgCIf5AVy-WU',
#    'scope': 'GOOGLE',
#    'types': ['locality', 'political'],
#    'vicinity': 'Torata District'}],
#  'status': 'OK'}

# %%
cities_list = ideal_weather_df["City"]
for city in cities_list:
    print(f"{city} is there")
# Out:
# Torata is there
# Port Keats is there
# Djambala is there
# Castro is there
# Stettler is there
# Polson is there
# Comarapa is there
# Afyonkarahisar is there
# Buritizeiro is there
# Ipameri is there
# Sioux Lookout is there
# San Cristobal is there
# Ushtobe is there
# Tyup is there
# Ladozhskaya is there
# Mwinilunga is there
# Kalabo is there
# Bethel is there
# São Sebastião do Paraíso is there
# Albanel is there
# Changji is there
# Palmer is there
# Vysokyy is there
# Ouro Branco is there
# Menongue is there
# Denizli Province is there
# Karakol is there
# Pompéia is there
# Aksarayskiy is there
# Emba is there
# Kananga is there
# Beroroha is there
# Sucúa is there
# Joensuu is there
# Linhares is there
# Fort Nelson is there
# Buritis is there
# Camabatela is there
# Saurimo is there
# Kharabali is there
# Tshikapa is there
